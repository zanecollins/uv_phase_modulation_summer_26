# %% [markdown]
# # UV-Phase Modulation Experiment Summer '26
#
# Last updated 06/29/2026
#
# Moku:Lab Lock-in Amplifier CSV parser + tau fitting pipeline for UV-Phase modulation lifetime experiments.

# %% [markdown]
# ## Experimental Notes
#
# The lifetime of an atom $\tau$ is extracted from the phase lag $\phi$ via the relation:
#
# $$
# \begin{align}
#     \tan(\phi) = \omega \tau \Rightarrow \tau = \frac{\tan(\phi)}{2\pi f}
# \end{align}
# $$
#
# where $\omega = 2\pi f$ and $f$ is the input modulation frequency.

# %% [markdown]
# ## What to record from Moku:lab
#
#
# \begin{aligned}
# &\bullet \text{Modulation frequency $f$ [Hz]} \\
# &\bullet \text{Lock-in outputs X and Y [Voltz]} \\
# &\bullet \text{}
# \end{aligned}

# %% [markdown]
# ## This notebook:
#
# Compute:
#
# \begin{aligned}
# &\bullet \text{$\tan(\phi) = \frac{Y}{X}$} \\
# &\bullet \text{$\tau = \frac{\tan(\phi)}{\omega}$} \\
# &\bullet \text{Can take multiple trials, average and take SEM to do experimental analysis and model fitting for confidence estimates}
# \end{aligned}

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import re
from pathlib import Path
from io import StringIO
from scipy import stats
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Helper Functions

# %% [markdown]
# # Data Parsing

# %%
os.join()
# Out:
# '/Users/zaniaccollins/Research/uv_phase_modulation'

# %%
data_dir = '/data/MokuLockInAmplifierData_20260629_143748.csv'

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 parse_moku_lockin_csv(data_dir)
#
# Cell In[10], line 4, in parse_moku_lockin_csv(path)
#       2 """Robust loader for Moku exported CSVs with % header comments."""
#       3 path = Path(path)
# ----> 4 with open(path, 'r', newline='') as f:
#       5     lines = f.readlines()
#       7 f_hz = None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# ...
