# %%
import pandas as pd

# %%
import pandas as pd
combo = pd.read_csv("/Users/mauriellenoto/Desktop/seager/uvphasedelay/data/a1/combined/a1xcombinedtrials.csv", )
dec_index = list(range(0,len(combo),100))
combo = combo.iloc[dec_index, :]
combo
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 combo = pd.read_csv("/Users/mauriellenoto/Desktop/seager/uvphasedelay/data/a1/combined/a1xcombinedtrials.csv", )
#       3 dec_index = list(range(0,len(combo),100))
#       4 combo = combo.iloc[dec_index, :]
#       5 combo
#
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(combo['Time (s)'], combo['Avg. Quadrature (V)'])
plt.ylabel("Time (s)")
plt.xlabel("Block A Quadrature (V)")
plt.title("X, every 100 data points")
# Out:
# Text(0.5, 1.0, 'X, every 100 data points')
